# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

x = np.random.normal(size=1000)
sns.distplot(x);

# %% [markdown]
# y = [y/1000 for y in range(1000)]

# %%
x = np.random.standard_exponential(size = 1000)
sns.distplot(x);

# %%
shape, scale = 1., 1.
x = np.random.standard_gamma(shape, size=1000)
sns.distplot(x);

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

plt.show()

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
# %matplotlib inline


x = np.random.uniform(-1,1,10000)
n, bins, patches = plt.hist(x, 100, normed=1, facecolor='black', alpha=0.75)
plt.show()

x_ = np.array([])
smplsz = 12
for j in range(10000):
    mysum = 0
    for i in range(smplsz):
        mysum = mysum + (x[np.random.random_integers(len(x)-1)])
    x_ = np.append(x_, [mysum/smplsz])

n, bins, patches = plt.hist(x_, 100, normed=1, facecolor='black', alpha=0.75)
print("mean of mean of 12 samples x_=", np.mean(x_))
print("mean of uniform distribution x= ", np.mean(x))

print("std x=", np.std(x, axis=0))
print("standard error x=",np.std(x)/np.sqrt(10000))

plt.show()

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# %matplotlib inline


def extractmeans(x):
    x_ = np.array([])
    smplsz = 12
    for j in range(100):
        mysum = 0
        for i in range(smplsz):
            mysum = mysum + (x[np.random.random_integers(len(x)-1)])
        x_ = np.append(x_, [mysum/smplsz])
    return x_

x = np.array([0])
for i in range(100):
    if i <= 37:
         x = np.append(x, 1)
    else:
        x = np.append(x,0)
np.random.shuffle(x)

print(x)
n, bins, patches = plt.hist(x, 100, facecolor='black', rwidth=1, alpha=0.75 )
plt.ylim([0,100])
plt.xlim([-0.5,1.5])
plt.show()


x_ = extractmeans(x)
n, bins, patches = plt.hist(x_, 100, normed=1, facecolor='black', alpha=0.75)
plt.show
print("mean of mean of 12 samples x_=", np.mean(x_))
print("mean of uniform distribution x= ", np.mean(x))
print("std x_ =", np.std(x, axis=0))
print("standard error x_ =",np.std(x_)/np.sqrt(10000))

# %%
# Z-distribution vs T-distribution
import scipy.stats as sc
import math


from scipy import stats

x = np.linspace(-10, 10, 1000)
fig, ax = plt.subplots(figsize=(10, 7.5))
for i in range(29):
    dist = sc.t(i+1, 0)
    plt.plot(x, dist.pdf(x), c='gray')
    
plt.plot(x,mlab.normpdf(x, 0, 1),c='black')
plt.show()

# %%
import numpy as np
from scipy.stats import t as student_t
from matplotlib import pyplot as plt



#------------------------------------------------------------
# Define the distribution parameters to be plotted
mu = 0
k_values = [1E10, 2, 1, 0.5]
linestyles = ['-', '--', ':', '-.']
x = np.linspace(-10, 10, 1000)

#------------------------------------------------------------
# plot the distributions
fig, ax = plt.subplots(figsize=(5, 3.75))

for k, ls in zip(k_values, linestyles):
    dist = student_t(k, 0)

    if k >= 1E10:
        label = r'$\mathrm{t}(k=\infty)$'
    else:
        label = r'$\mathrm{t}(k=%.1f)$' % k

    plt.plot(x, dist.pdf(x), ls=ls, c='black', label=label)

#plt.plot(x,mlab.normpdf(x, 0, 1),c='red')
plt.xlim(-5, 5)
plt.ylim(0.0, 0.45)

plt.xlabel('$x$')
plt.ylabel(r'$p(x|k)$')
plt.title("Student's $t$ Distribution")

plt.legend()
plt.show()

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# %matplotlib inline


def extractmeans(x):
    x_ = np.array([])
    smplsz = 12
    for j in range(100):
        mysum = 0
        for i in range(smplsz):
            mysum = mysum + (x[np.random.random_integers(len(x)-1)])
        x_ = np.append(x_, [mysum/smplsz])
    return x_

x = np.array([0])
for i in range(100):
    if i <= 37:
         x = np.append(x, 1)
    else:
        x = np.append(x,0)
np.random.shuffle(x)

print(x)
n, bins, patches = plt.hist(x, 100, facecolor='black', rwidth=1, alpha=0.75 )
plt.ylim([0,100])
plt.xlim([-0.5,1.5])
plt.show()


x_ = extractmeans(x)
n, bins, patches = plt.hist(x_, 100, normed=1, facecolor='black', alpha=0.75)
plt.show
print("mean of mean of 12 samples x_=", np.mean(x_))
print("mean of uniform distribution x= ", np.mean(x))
print("std x_ =", np.std(x, axis=0))
print("standard error x_ =",np.std(x_)/np.sqrt(10000))
print('done')
